# %% [markdown]
# # SHAPE  - Introductory Computer Science
# ---
#
#
# ## Object Oriented Programming: Classes and Attributes

# %% [markdown]
# Object Oriented Programming (OOP) is an important approach to programming and problem solving.
#
# Many of concepts we will discuss in this lecture will appear familiar. That's because we have been taking an Object-Oriented perspective on programming all along. Python is an object-oriented language and almost everything in Python is an object.
#
#    * We made a clear distinction between names (variables) and the objects they refer to.
#    * We focused on the operations supported by different data types.

# %% [markdown]
# **Core idea**: Objects bundle data together with a set of functionality defined by the data type.

# %%
li = list()

# %%
li.append(4) # method call

# %%
li
# Out:
# [4]

# %%
len(li) # built-in function
# Out:
# 1

# %%
len(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-91fed648bb37> in <module>
# ----> 1 len(5)
#
# TypeError: object of type 'int' has no len()

# %%
len("hello")
# Out:
# 5

# %%
li * 3 # built-in operators
# Out:
# [4, 4, 4]

# %%
'b' * 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-f775594baf4c> in <module>
# ----> 1 'b' * 'a'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
dir(li)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# Today we will discuss how to define **your own data types (classes)**, with their own specific structure and operations.

# %% [markdown]
# ## Classes and Instances
# A class is a data type defined by the programmer. The data type has
# * A name.
# * A set of **attributes**. There are two types of attributes:
#     * data fields: names for the data fields stored in this object. a.k.a. instance variables.
#     * methods: definitions for operations that can be performed on objects of this type.

# %% [markdown]
# ### Example: Library System
#
# A library has a number of books.
# * What should the data associated with each book be?
# * Are there any operations that a book should support?

# %%
class LibraryBook():
    """
    This data type represents a library book. 
    """
    pass

# %% [markdown]
# `LibraryBook` is the name of the class.
#
# `pass` indicates that the body/suit of the class definition is empty.
#
# class definitions can have a *doc string*, just like functions.

# %%
type(LibraryBook)
# Out:
# type

# %%
type(int)
# Out:
# type

# %% [markdown]
# Classes are **blueprints** for instances. The relationship between a class and an instance is similar to the one between a cookie cutter and a cookie.
#    * A single cookie cutter can make any number of cookies. The cutter defines the shape of the cookie.
#    * The cookies are edible, but the cookie cutter is not.
#
# **To create an instance** from a class, simply "call" the name of the class. This looks like a function call, but instead it creates a new instance.

# %%
li = list()

# %%
li
# Out:
# []

# %%
my_book = LibraryBook()

# %%
my_book

# %%
type(li)
# Out:
# list

# %%
type(my_book)
# Out:
# __main__.LibraryBook

# %%
another_book = LibraryBook()

# %%
another_book

# %%
another_book is my_book
# Out:
# False

# %%
my_book.__class__
# Out:
# __main__.LibraryBook

# %%
li.__class__
# Out:
# list

# %%
dir(my_book)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
dir(li)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
isinstance(my_book, LibraryBook)
# Out:
# True

# %%
isinstance(my_book, list)
# Out:
# False

# %%
isinstance([1,2,3], list)
# Out:
# True

# %% [markdown]
# ### Instance Attributes

# %% [markdown]
# There are two types of instance attributes:
#    * **Data fields**. Each instance owns its own data (the class can define what names the data fields have).
#    * **Methods** containing the functionality of the object. These are defined in the class.

# %%
my_book.title = "The Hitchhikers Guide to the Galaxy"
my_book.author = ('Adams', 'Douglas')
my_book.year = 1979
my_book.isbn = "9780345391803"
my_book.color = "blue"

# %%
my_book.title
# Out:
# 'The Hitchhikers Guide to the Galaxy'

# %%
my_book.author
# Out:
# ('Adams', 'Douglas')

# %%
dir(my_book)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'author',
#  'color',
#  'isbn',
#  'title',
#  'year']

# %% [markdown]
# Method definitions look like function definitions, but they happen inside a class definition. They always have a special `self` parameter that is automatically bound to the instance when the method is called.

# %%
my_book

# %%
class LibraryBook(object):
    """
    A library book.
    """
        
    def set_title(self, new_title):  # Self refers to the instance that the method is called on.
        """
        Set the title of this book
        """
        self.title = new_title 
    
    def title_and_author(self):
        return "{} {}: {}".format(self.author[1], self.author[0], self.title)

# %%
my_book = LibraryBook()
my_book.set_title("Test Book")

# %%
my_book.title
# Out:
# 'Test Book'

# %%
my_book.title_and_author()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-64c2e6a83e6e> in <module>
# ----> 1 my_book.title_and_author()
#
# <ipython-input-41-76fa1b01c0ea> in title_and_author(self)
#      11
#      12     def title_and_author(self):
# ---> 13         return "{} {}: {}".format(self.author[1], self.author[0], self.title)
#
# AttributeError: 'LibraryBook' object has no attribute 'author'

# %%
my_book.title = "The Hitchhikers Guide to the Galaxy"
my_book.author = ('Adams', 'Douglas')
my_book.year = 1979
my_book.isbn = "9780345391803"
my_book.color = "blue"

# %%
my_book.title_and_author()
# Out:
# 'Douglas Adams: The Hitchhikers Guide to the Galaxy'

# %%
my_book.set_title("H2G2")

# %%
my_book.title # title has changed
# Out:
# 'H2G2'

# %%
my_book.title_and_author()
# Out:
# 'Douglas Adams: H2G2'

# %%
dir(my_book)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'author',
#  'color',
#  'isbn',
#  'set_title',
#  'title',
#  'title_and_author',
#  'year']

# %%
my_book.title_and_author
# Out:
# <bound method LibraryBook.title_and_author of <__main__.LibraryBook object at 0x7fc2984ddd00>>

# %% [markdown]
# ### Python special methods
#
# * Classes contain a number of **special methods** that allow you to create some useful functionality for classes.
#
# * The most important of these is the `__init__(self, ...)` method, that is automatically called by Python when a new instance is created. This method is called the class' **constructor**
#
# * Instead of setting data fields from outside once the instance has been created (like we did above; this is considered bad style), we usually want to pass some initial data to the instance when it is created.

# %%
class LibraryBook(object):
    """
    A library book.
    """
         
    # Constructor!
    def __init__(self, title, author, pub_year, call_no):
        self.title = title
        self.author = author
        self.year = pub_year
        self.call_number = call_no
        self.checked_out = False 
        
    def title_and_author(self):
        return "{} {}: {}".format(self.author[1], self.author[0], self.title)

# %%
new_book = LibraryBook("Hitchhiker's Guide to the Galaxy", ("Adams","Douglas"), 1979, "9780345391803")

# %%
new_book.title_and_author()
# Out:
# "Douglas Adams: Hitchhiker's Guide to the Galaxy"

# %%
new_book.checked_out
# Out:
# False

# %%
bookshelf = []
for i in range(10):
    new_book = LibraryBook("Hitchhiker's Guide to the Galaxy", ("Adams","Douglas"), 1979, "9780345391803")
    bookshelf.append(new_book)

# %%
bookshelf
# Out:
# [<__main__.LibraryBook at 0x7fc298520b80>,
#  <__main__.LibraryBook at 0x7fc2985204f0>,
#  <__main__.LibraryBook at 0x7fc298520be0>,
#  <__main__.LibraryBook at 0x7fc2985206a0>,
#  <__main__.LibraryBook at 0x7fc298520c70>,
#  <__main__.LibraryBook at 0x7fc298520d00>,
#  <__main__.LibraryBook at 0x7fc298520d60>,
#  <__main__.LibraryBook at 0x7fc298520dc0>,
#  <__main__.LibraryBook at 0x7fc298520e50>,
#  <__main__.LibraryBook at 0x7fc298520eb0>]

# %%
bookshelf[1]

# %% [markdown]
# Another useful method is `__str__`, which is used to convert the instance into a string, for example when it is printed, or when the str() built-in function is applied to the instance.

# %%
print(new_book)
# Out:
# <__main__.LibraryBook object at 0x7fc298520eb0>

# %%
str(new_book)
# Out:
# '<__main__.LibraryBook object at 0x7fc298520eb0>'

# %%
li = [1,2,3,4]
print(li)
# Out:
# [1, 2, 3, 4]

# %%
str(li)
# Out:
# '[1, 2, 3, 4]'

# %%
li
# Out:
# [1, 2, 3, 4]

# %%
class LibraryBook(object):
    """
    A library book.
    """
         
    def __init__(self, title, author, pub_year, call_no):
        self.title = title
        self.author = author
        self.year = pub_year
        self.call_number = call_no
        
    def title_and_author(self):
        return "{} {}: {}".format(self.author[1], self.author[0], self.title) 
    
    def __str__(self): #make sure that __str__ returns a string!
        return "{} {} ({}): {}".format(self.author[1], self.author[0], self.year, self.title)

# %%
new_book = LibraryBook("Hitchhiker's Guide to the Galaxy", ("Adams","Douglas"), 1979, "9780345391803")

# %%
print(new_book)
# Out:
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy

# %%
s = str(new_book)
s
# Out:
# "Douglas Adams (1979): Hitchhiker's Guide to the Galaxy"

# %%
new_book

# %%
bookshelf = []
for i in range(10):
    bookshelf.append(LibraryBook("Hitchhiker's Guide to the Galaxy", ("Adams","Douglas"), 1979, "9780345391803"))

# %%
bookshelf
# Out:
# [<__main__.LibraryBook at 0x7fc2984dde20>,
#  <__main__.LibraryBook at 0x7fc2984dd700>,
#  <__main__.LibraryBook at 0x7fc298520910>,
#  <__main__.LibraryBook at 0x7fc298520a90>,
#  <__main__.LibraryBook at 0x7fc298520730>,
#  <__main__.LibraryBook at 0x7fc298520fa0>,
#  <__main__.LibraryBook at 0x7fc298520460>,
#  <__main__.LibraryBook at 0x7fc2985205e0>,
#  <__main__.LibraryBook at 0x7fc298520550>,
#  <__main__.LibraryBook at 0x7fc298520160>]

# %% [markdown]
# Finally, the `__repr__` method defines what iPython prints out on the console when you inspect the object.

# %%
new_book

# %%
class LibraryBook(object):
    """
    A library book.
    """
         
    def __init__(self, title, author, pub_year, call_no):
        self.title = title
        self.author = author
        self.year = pub_year
        self.call_number = call_no
        
    def title_and_author(self):
        return "{} {}: {}".format(self.author[1], self.author[0], self.title) 
    
    def __str__(self): #make sure that __str__ returns a string!
        return "{} {} ({}): {}".format(self.author[1], self.author[0], self.year, self.title) 
        
    def __repr__(self): 
        return "<LibraryBook: {} ({})>".format(self.title, self.call_number)

# %%
new_book = LibraryBook("Hitchhiker's Guide to the Galaxy", ("Adams","Douglas"), 1979, "9780345391803")

# %%
new_book
# Out:
# <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>

# %%
print(new_book)
# Out:
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy

# %%
bookshelf = []
for i in range(10):
    new_book = LibraryBook("Hitchhiker's Guide to the Galaxy", ("Adams","Douglas"), 1979, "9780345391803")
    bookshelf.append(new_book)

# %%
print(bookshelf)
# Out:
# [<LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>, <LibraryBook: Hitchhiker's Guide to the Galaxy (9780345391803)>]

# %%
for book in bookshelf: 
    print(book)
# Out:
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy
# Douglas Adams (1979): Hitchhiker's Guide to the Galaxy

# %% [markdown]
# ## Why use classes and when?

# %% [markdown]
# Objects simplify problems by providing an **abstraction** over certain data types and their functionality.
#   * Instead of thinking of the problem in terms of individual strings, integers, etc. we can now think in terms of LibraryBooks (or other objects).
#   * Another programmer using your classes does not have to worry about _how_ the methods are implemented or how data is stored in instances of your class.

# %% [markdown]
# ## Three important OOP concepts
#
# * Encapsulation
# * Polymorphism (Not discussed)
# * Inheritance (Not discussed)

# %%
class LibraryMedia:
    
    def __init__(self, call_number):
        self.call_number = call_number
        self.checked_out = False
        
    def check_out(self):
        self.checked_out = True
        
    def is_checked_out(self):
        return self.checked_out
        
    def return_media(self):
        self.checked_out = False
        
class LibraryBook(LibraryMedia):
    
    def __init__(self, author, title, call_number, year):
        
        self.author = author
        self.title = title
        self.call_number = call_number
        self.year = year
        self.checked_out = False

# %%
b = LibraryBook("Jane Doe", "A fancy book", 1, 2021)

# %%
b.is_checked_out()
# Out:
# False

# %%
b.check_out()

# %%
b.checked_out
# Out:
# True

# %%
type(object)
# Out:
# type

# %% [markdown]
# ### Encapsulation
#
# * Data and functionality is bundled in objects.
# * The methods provide an *interface* to the object. Ideally the individual data are **only** written and read through methods.
# * This means that details about *how* the functionality is implemented is hidden from the programmer. For example, we don't know how the append method on lists is implemented.
# * This idea allow classes to be shared (in libraries) and used by others (or re-used by you) without having to read through the source code for the class.
